# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsrivastava096/Python-Tutorial/blob/main/Pyhton_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# # NUMPY

# %%
a = 10
b = 20
c = a+b
c
c = 15
c
# Out:
# 15

# %%
d = a * b
d
e = b - a
e
# Out:
# 10
