# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsrivastava096/Python-Tutorial/blob/main/Python_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# # NUMPY

# %%
# Type knowing
l=[1,2,3,4,5]
type(l)
l
# Out:
# [1, 2, 3, 4, 5]

# %%
#Creation of array
arr= np.array([1,2,3,4,5])
arr

# %%
#element-wise operation
arr+2

# %%
# Addition of Array
a = 10
b = 20
c = a+b
c
# Out:
# 30

# %%
# Substraction of Array
a = 10
b = 20
c = b-a
c
# Out:
# 10

# %%
# Multiplication of Array
a = 10
b = 20
c = a*b
c
# Out:
# 200

# %%
# division of Array
a = 10
b = 20
c = b/a
c
# Out:
# 2.0

# %%
arr=np.array([True])
arr=np.array([False])
arr=np.array([True,1])
arr=np.array([True,1,2.5])
arr=np.array([True,1,2.5,6+5j])
arr=np.array([True,1,2.5,6+5j,"numpy"])
arr=np.array([True,1,2.5,6+5j,"numpy",{1,2}])
arr=np.array([True,1,2.5,6+5j,"numpy",{1,2},{1:"a",2:"b"}])

print(arr)
print(arr.dtype)
# Out:
# [False]
# bool

# %%
#[20,40,60,80,30,50]
arr1=np.array([20,40,60,80,30,50])
arr1
# Out:
# array([20, 40, 60, 80, 30, 50])

# %%
# [10,20,35.6,80]
ar2=np.array([10,20,35.6,80])
print(ar2)
ar2.dtype
# Out:
# dtype('float64')

# %%
# {10,"numpy",30,"Hi"}
ar3=np.array({10,"numpy",30,"Hi"})
print(ar3)
ar3.dtype
# Out:
# {'numpy', 10, 'Hi', 30}
# dtype('O')

# %%
# ["bye",6+8j,{"d":12,"e":45},67.9]
l=["bye",6+8j,{"d":12,"e":45},67.9]
ar4=np.array(l)
print(ar4)
ar4.dtype
# Out:
# ['bye' (6+8j) {'d': 12, 'e': 45} 67.9]
# dtype('O')

# %%
#Typecasting using astype() part1
ar5=np.array([1,2,3])
b5= ar5.astype(bool)
print(b5)
b5.dtype
# Out:
# [ True  True  True]
# dtype('bool')

# %%
#typecasting using astype() part2

arr=np.array(["1","2","67.78","65"])
bl=arr.astype(float)
print(bl)
bl.dtype
# Out:
# [ 1.    2.   67.78 65.  ]
# dtype('float64')

# %%
# Want Output as [False,Str,Object]
ar6 = np.array([False, "Str", object])
print(ar6)
# Out:
# [False 'Str' <class 'object'>]

# %%
# Checking Dimension
ar7= np.array([1,2,3,4])
print(ar7)
arr.ndim
# Out:
# [1 2 3 4]
# 1

# %%
# Two Dimension Array
ar8=np.array([[1,2,5],[3,4,6]])
print(ar8)
ar8.ndim
# Out:
# [[1 2 5]
#  [3 4 6]]
# 2
